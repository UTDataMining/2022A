# %% [markdown]
# <a href="https://colab.research.google.com/github/UTDataMining/2021A/blob/master/SSDSE/SSDSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 教育用標準データセット：A. 市区町村別、多分野データ
# !wget https://raw.githubusercontent.com/UTDataMining/2021A/master/SSDSE/SSDSE-2020A.csv
# Out:
# --2021-10-25 06:04:27--  https://raw.githubusercontent.com/UTDataMining/2021A/master/SSDSE/SSDSE-2020A.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 983452 (960K) [text/plain]
# Saving to: ‘SSDSE-2020A.csv.2’
#
# SSDSE-2020A.csv.2   100%[===================>] 960.40K  --.-KB/s    in 0.05s
#
# 2021-10-25 06:04:27 (19.6 MB/s) - ‘SSDSE-2020A.csv.2’ saved [983452/983452]

# %%
import pandas as pd
df = pd.read_csv('SSDSE-2020A.csv', header=2)

# %%
df
# Out:
#        地域コード 都道府県  市区町村      総人口  総人口（男）  ...   医師数  歯科医師数  薬剤師数  保育所等数  保育所等在所児数
# 0     R01100  北海道   札幌市  1952356  910614  ...  6614   2113  5398    287     26613
# 1     R01202  北海道   函館市   265979  120376  ...   801    183   680     49      3524
# 2     R01203  北海道   小樽市   121924   54985  ...   322    102   326     22      1370
# 3     R01204  北海道   旭川市   339605  156402  ...  1339    254   867     67      5715
# 4     R01205  北海道   室蘭市    88564   43143  ...   272     63   196     10      1039
# ...      ...  ...   ...      ...     ...  ...   ...    ...   ...    ...       ...
# 1736  R47361  沖縄県  久米島町     7755    4086  ...     7      2     6      4       274
# 1737  R47362  沖縄県  八重瀬町    29066   14247  ...    71     18    33     14      1439
# 1738  R47375  沖縄県  多良間村     1194     639  ...     1      2     0      1        23
# 1739  R47381  沖縄県   竹富町     3998    2057  ...     6      2     0      0         0
# ...
