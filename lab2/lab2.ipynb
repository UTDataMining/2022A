# %% [markdown]
# <a href="https://colab.research.google.com/github/UTDataMining/2022A/blob/main/lab2/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install japanize_matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import japanize_matplotlib 
import seaborn as sns
import numpy as np

# %%
# 教育用標準データセット：A. 市区町村別、多分野データ
# !wget https://raw.githubusercontent.com/UTDataMining/2022A/master/lab2/SSDSE-2020A.csv

# %%
import pandas as pd
df = pd.read_csv('SSDSE-2020A.csv', header=2)

# %%
df
# Out:
#        地域コード 都道府県  市区町村      総人口  総人口（男）   総人口（女）    日本人人口  日本人人口（男）  \
# 0     R01100  北海道   札幌市  1952356  910614  1041742  1937785    903535
# 1     R01202  北海道   函館市   265979  120376   145603   264537    119819
# 2     R01203  北海道   小樽市   121924   54985    66939   121415     54722
# 3     R01204  北海道   旭川市   339605  156402   183203   335678    154716
# 4     R01205  北海道   室蘭市    88564   43143    45421    88203     42935
# ...      ...  ...   ...      ...     ...      ...      ...       ...
# 1736  R47361  沖縄県  久米島町     7755    4086     3669     7721      4070
# 1737  R47362  沖縄県  八重瀬町    29066   14247    14819    28916     14175
# 1738  R47375  沖縄県  多良間村     1194     639      555     1180       637
# 1739  R47381  沖縄県   竹富町     3998    2057     1941     3960      2046
# 1740  R47382  沖縄県  与那国町     1843    1147      696     1832      1141
#
#       日本人人口（女）  15歳未満人口  ...  飲食店数  大型小売店数  一般病院数  一般診療所数  歯科診療所数   医師数  \
# ...

# %%
df.sort_values('総人口').head(10)
# Out:
#       地域コード 都道府県  市区町村  総人口  総人口（男）  総人口（女）  日本人人口  日本人人口（男）  日本人人口（女）  \
# 398  R07543  福島県   富岡町    0       0       0      0         0         0
# 400  R07545  福島県   大熊町    0       0       0      0         0         0
# 401  R07546  福島県   双葉町    0       0       0      0         0         0
# 402  R07547  福島県   浪江町    0       0       0      0         0         0
# 403  R07548  福島県   葛尾村   18      12       6     18        12         6
# 405  R07564  福島県   飯舘村   41       7      34     41         7        34
# 687  R13402  東京都  青ヶ島村  178     107      71    177       107        70
# 685  R13382  東京都  御蔵島村  335     189     146    334       189       145
# 681  R13362  東京都   利島村  337     191     146    336       191       145
# 751  R15586  新潟県  粟島浦村  370     184     186    369       184       185
#
#      15歳未満人口  ...  飲食店数  大型小売店数  一般病院数  一般診療所数  歯科診療所数  医師数  歯科医師数  薬剤師数  \
# 398        0  ...     0       0      0       2       0    2      0     2
# ...

# %%
df[df['総人口'] == 0]
# Out:
#       地域コード 都道府県 市区町村  総人口  総人口（男）  総人口（女）  日本人人口  日本人人口（男）  日本人人口（女）  \
# 398  R07543  福島県  富岡町    0       0       0      0         0         0
# 400  R07545  福島県  大熊町    0       0       0      0         0         0
# 401  R07546  福島県  双葉町    0       0       0      0         0         0
# 402  R07547  福島県  浪江町    0       0       0      0         0         0
#
#      15歳未満人口  ...  飲食店数  大型小売店数  一般病院数  一般診療所数  歯科診療所数  医師数  歯科医師数  薬剤師数  \
# 398        0  ...     0       0      0       2       0    2      0     2
# 400        0  ...     0       0      0       2       0    2      0     0
# 401        0  ...     0       0      0       0       0    0      0     0
# 402        0  ...     0       0      0       1       0    0      1     3
#
#      保育所等数  保育所等在所児数
# 398      0         0
# 400      0         0
# 401      0         0
# 402      0         0
#
# [4 rows x 128 columns]

# %%
df['総人口'].hist(bins=100, log=True);

# %%
df['総人口'].plot.box();

# %%
df.sort_values('総人口', ascending=False).head(10)
# Out:
#        地域コード  都道府県   市区町村      総人口   総人口（男）   総人口（女）    日本人人口  日本人人口（男）  \
# 689   R14100  神奈川県    横浜市  3724844  1855985  1868859  3623330   1803061
# 1112  R27100   大阪府    大阪市  2691185  1302562  1388623  2497380   1205611
# 984   R23100   愛知県   名古屋市  2295638  1133640  1161998  2213811   1095360
# 0     R01100   北海道    札幌市  1952356   910614  1041742  1937785    903535
# 1468  R40130   福岡県    福岡市  1538681   726666   812015  1478656    696551
# 1155  R28100   兵庫県    神戸市  1537272   726700   810572  1480458    698836
# 690   R14130  神奈川県    川崎市  1475213   749038   726175  1417032    719166
# 1086  R26100   京都府    京都市  1475183   699748   775435  1412924    670798
# 510   R11100   埼玉県  さいたま市  1263979   627238   636741  1231350    611137
# 1330  R34100   広島県    広島市  1194034   576850   617184  1172808    566858
#
#       日本人人口（女）  15歳未満人口  ...   飲食店数  大型小売店数  一般病院数  一般診療所数  歯科診療所数   医師数  \
# 689    1820269   468535  ...  12495     499    114    2977    2078  8442
# ...

# %%
df['総人口'].describe()
# Out:
# count    1.741000e+03
# mean     7.300100e+04
# std      1.880053e+05
# min      0.000000e+00
# 25%      8.202000e+03
# 50%      2.462200e+04
# 75%      6.343100e+04
# max      3.724844e+06
# Name: 総人口, dtype: float64

# %%
df['log population']=np.log(df['総人口']+1)

# %%
df['log population'].describe()
# Out:
# count    1741.000000
# mean       10.046099
# std         1.589710
# min         0.000000
# 25%         9.012255
# 50%        10.111436
# 75%        11.057724
# max        15.130536
# Name: log population, dtype: float64

# %%
df['log population'].hist(bins=100);

# %%
df['log population'].plot.box();

# %%
df[['市区町村','総人口','log population']].sort_values('log population').head(10)
# Out:
#      市区町村  総人口  log population
# 398   富岡町    0        0.000000
# 400   大熊町    0        0.000000
# 401   双葉町    0        0.000000
# 402   浪江町    0        0.000000
# 403   葛尾村   18        2.944439
# 405   飯舘村   41        3.737670
# 687  青ヶ島村  178        5.187386
# 685  御蔵島村  335        5.817111
# 681   利島村  337        5.823046
# 751  粟島浦村  370        5.916202

# %%
df[['市区町村','総人口','log population']].sort_values('log population', ascending=False).head(10)
# Out:
#        市区町村      総人口  log population
# 689     横浜市  3724844       15.130536
# 1112    大阪市  2691185       14.805493
# 984    名古屋市  2295638       14.646522
# 0       札幌市  1952356       14.484548
# 1468    福岡市  1538681       14.246437
# 1155    神戸市  1537272       14.245521
# 690     川崎市  1475213       14.204314
# 1086    京都市  1475183       14.204293
# 510   さいたま市  1263979       14.049776
# 1330    広島市  1194034       13.992849
